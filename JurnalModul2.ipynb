# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread("Assets/aktivis.jpg")
plt.imshow(img, "gray")

# %%
# plt.subplot(1, 6, 6)
# mc1 = plt.imshow(img[:,900:1300])
# plt.axis('off')

# plt.subplot(1, 6, 5)
# mc2 = plt.imshow(img[:,1800:2200])
# plt.axis('off')

# plt.subplot(1, 6, 4)
# mc3 = plt.imshow(img[:,0:400])
# plt.axis('off')

# plt.subplot(1, 6, 3)
# mc4 = plt.imshow(img[:,1400:1800])
# plt.axis('off')

# plt.subplot(1, 6, 2)
# mc5 = plt.imshow(img[:,2320:2800])
# plt.axis('off')

# plt.subplot(1, 6, 1)
# mc6 = plt.imshow(img[:,500:900])
# plt.axis('off')

# %%
mc1 = (img[:,900:1300])
mc2 = (img[:,1800:2200])
mc3 = (img[:,0:400])
mc4 = (img[:,1400:1800])
mc5 = (img[:,2320:2800])
mc6 = (img[:,500:900])

plt.subplot(1, 6, 6)
plt.imshow(mc1)
plt.axis('off')

plt.subplot(1, 6, 5)
plt.imshow(mc2)
plt.axis('off')

plt.subplot(1, 6, 4)
plt.imshow(mc3)
plt.axis('off')

plt.subplot(1, 6, 3)
plt.imshow(mc4)
plt.axis('off')

plt.subplot(1, 6, 2)
plt.imshow(mc5)
plt.axis('off')

plt.subplot(1, 6, 1)
plt.imshow(mc6)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(1293.5), np.float64(-0.5))

# %%
timeline = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)

print(img.shape)
print(mc1.shape)
print(mc2.shape)
print(mc3.shape)
print(mc4.shape)
print(mc5.shape)
print(mc6.shape)

timeline[:,:400]=mc1
timeline[:,400:800]=mc2
timeline[:,800:1200]=mc3
timeline[:,1200:1800]=mc4
timeline[:,1800:2100]=mc5
timeline[:,2100:2500]=mc6

plt.imshow(timeline)
# Out:
# (1294, 2722, 3)
# (1294, 400, 3)
# (1294, 400, 3)
# (1294, 400, 3)
# (1294, 400, 3)
# (1294, 402, 3)
# (1294, 400, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 14
#      12 timeline[:,400:800]=mc2
#      13 timeline[:,800:1200]=mc3
# ---> 14 timeline[:,1200:1800]=mc4
#      15 timeline[:,1800:2100]=mc5
#      16 timeline[:,2100:2500]=mc6
#
# ValueError: could not broadcast input array from shape (1294,400,3) into shape (1294,600,3)
